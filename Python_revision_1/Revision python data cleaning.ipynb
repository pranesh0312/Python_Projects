# %%
import pandas as pd

# %%
df=pd.read_csv("titanic_train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.drop(columns="PassengerId",inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()*100/len(df)
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df.drop(columns="Cabin",inplace=True)

# %%
df["Embarked"].fillna(df["Embarked"].mode()[0],inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(select_dtypes=numeric)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.boxplot(select_dtypes=numeric)
#
# NameError: name 'numeric' is not defined

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
import numpy as np
df["Age"]=np.log1p(df["Age"])

# %%
df["Sibsp"]=np.log1p(df.Sibsp)
df["Fare"]=np.log1p(df.Fare)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13104\2789593603.py in ?()
# ----> 1 df["Sibsp"]=np.log1p(df.Sibsp)
#       2 df["Fare"]=np.log1p(df.Fare)
#
# D:\python\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Sibsp'

# %%
df["Fare"]=np.log1p(df.Fare)

# %%
df_corr=df.

# %%
sns.scatterplot(data=df,x="Fare",y="Age",hue="Survived")
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
df.select_dtypes(include="object")
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Embarked
# 0           A/5 21171        S
# 1            PC 17599        C
# 2    STON/O2. 3101282        S
# 3              113803        S
# 4              373450        S
# ...

# %%
sns.swarmplot(data=df,x="Embarked",y="Pclass",hue="Survived")
# Out:
# D:\python\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 88.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\python\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\python\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 61.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Embarked', ylabel='Pclass'>
# D:\python\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 91.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.drop(columns=["Name","Ticket"],inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex       Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  3.135494      1      0  2.110213        S
# 1           1       1  female  3.663562      1      0  4.280593        C
# 2           1       3  female  3.295837      0      0  2.188856        S
# 3           1       1  female  3.583519      1      0  3.990834        S
# 4           0       3    male  3.583519      0      0  2.202765        S
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 886         0       2    male  3.332205      0      0  2.639057        S
# 887         1       1  female  2.995732      0      0  3.433987        S
# 888         0       3  female  3.367296      1      2  3.196630        S
# 889         1       1    male  3.295837      0      0  3.433987        C
# 890         0       3    male  3.496508      0      0  2.169054        Q
#
# [891 rows x 8 columns]

# %%
df=pd.get_dummies(df,dtype=int,drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
x=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
ss=StandardScaler()
x_train =ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.812199036918138

# %%
y_predict=lr.predict(x_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_predict)

# %%
df=pd.read_excel("Car+claims+for+insurance.xlsx")

# %%
df
# Out:
#              ID  KIDSDRIV      BIRTH  HOMEKIDS  YOJ  INCOME PARENT1  HOME_VAL  \
# 0     100130023         0 1955-02-05         2   13   26763     Yes    141019
# 1     100263241         0 1961-10-05         0    9  156060      No    381438
# 2     100321982         0 1959-11-12         1   11    1965     Yes         0
# 3     100391818         0 1961-10-11         1   10   62361      No    185738
# 4     100549277         0 1966-10-06         1   10   34192     Yes         0
# ...         ...       ...        ...       ...  ...     ...     ...       ...
# 7642  999532945         0 1938-08-28         0   11   67813      No    249997
# 7643  999575184         0 1968-12-24         2   11   13490      No     95447
# 7644  999612102         0 1957-03-27         1   11   44955      No    161808
# 7645  999756883         0 1951-06-09         0   13   36835      No    167142
# 7646  999799289         0 1952-07-21         0   13   58273      No    238850
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7647 entries, 0 to 7646
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          7647 non-null   int64
#  1   KIDSDRIV    7647 non-null   int64
#  2   BIRTH       7647 non-null   datetime64[ns]
#  3   HOMEKIDS    7647 non-null   int64
#  4   YOJ         7647 non-null   int64
#  5   INCOME      7647 non-null   int64
#  6   PARENT1     7647 non-null   object
#  7   HOME_VAL    7647 non-null   int64
#  8   MSTATUS     7647 non-null   object
#  9   GENDER      7647 non-null   object
#  10  EDUCATION   7647 non-null   object
#  11  OCCUPATION  7647 non-null   object
#  12  TRAVTIME    7647 non-null   int64
#  13  CAR_USE     7647 non-null   object
#  14  BLUEBOOK    7647 non-null   int64
#  15  CAR_TYPE    7647 non-null   object
#  16  OLDCLAIM    7647 non-null   int64
#  17  CLM_FREQ    7647 non-null   int64
#  18  CLM_AMT     7647 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  ID     KIDSDRIV                          BIRTH     HOMEKIDS  \
# count  7.647000e+03  7647.000000                           7647  7647.000000
# mean   5.526776e+08     0.171701  1954-09-30 09:24:55.645351168     0.741206
# min    1.001300e+08     0.000000            1930-03-14 00:00:00     0.000000
# 25%    3.290372e+08     0.000000            1948-10-23 00:00:00     0.000000
# 50%    5.503528e+08     0.000000            1954-07-28 00:00:00     0.000000
# 75%    7.792809e+08     0.000000            1960-09-08 12:00:00     1.000000
# max    9.997993e+08     4.000000            1986-02-18 00:00:00     5.000000
# std    2.598341e+08     0.509594                            NaN     1.129170
#
#                YOJ         INCOME       HOME_VAL     TRAVTIME      BLUEBOOK  \
# count  7647.000000    7647.000000    7647.000000  7647.000000   7647.000000
# mean     10.440173   57827.276318  149934.203478    33.662220  15176.001046
# ...

# %%
df.describe(include="object")
# Out:
#        PARENT1 MSTATUS GENDER    EDUCATION   OCCUPATION  CAR_USE CAR_TYPE  \
# count     7647    7647   7647         7647         7647     7647     7647
# unique       2       2      2            5            8        2        6
# top         No     Yes      F  High School  Blue Collar  Private      SUV
# freq      6619    4571   4273         2383         1853     5086     2264
#
#                  URBANICITY
# count                  7647
# unique                    2
# top     Highly Urban/ Urban
# freq                   6034

# %%
df.drop(columns="ID",inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# KIDSDRIV      0
# BIRTH         0
# HOMEKIDS      0
# YOJ           0
# INCOME        0
# PARENT1       0
# HOME_VAL      0
# MSTATUS       0
# GENDER        0
# EDUCATION     0
# OCCUPATION    0
# TRAVTIME      0
# CAR_USE       0
# BLUEBOOK      0
# CAR_TYPE      0
# OLDCLAIM      0
# CLM_FREQ      0
# CLM_AMT       0
# CAR_AGE       0
# URBANICITY    0
# dtype: int64

# %%
sns.boxplot(data=df.iloc[:,0:4])
# Out:
# <Axes: >

# %%
df
# Out:
#       KIDSDRIV      BIRTH  HOMEKIDS  YOJ  INCOME PARENT1  HOME_VAL MSTATUS  \
# 0            0 1955-02-05         2   13   26763     Yes    141019      No
# 1            0 1961-10-05         0    9  156060      No    381438     Yes
# 2            0 1959-11-12         1   11    1965     Yes         0      No
# 3            0 1961-10-11         1   10   62361      No    185738     Yes
# 4            0 1966-10-06         1   10   34192     Yes         0      No
# ...        ...        ...       ...  ...     ...     ...       ...     ...
# 7642         0 1938-08-28         0   11   67813      No    249997     Yes
# 7643         0 1968-12-24         2   11   13490      No     95447     Yes
# 7644         0 1957-03-27         1   11   44955      No    161808     Yes
# 7645         0 1951-06-09         0   13   36835      No    167142     Yes
# 7646         0 1952-07-21         0   13   58273      No    238850     Yes
#
# ...

# %%
df["BIRTH"].astype(str).str.split("-").str.get(0)
# Out:
# 0       1955
# 1       1961
# 2       1959
# 3       1961
# 4       1966
#         ...
# 7642    1938
# 7643    1968
# 7644    1957
# 7645    1951
# 7646    1952
# Name: BIRTH, Length: 7643, dtype: object

# %%
df["Age"]=2004-df["BIRTH"].astype(str).str.split("-").str.get(0).astype(int)

# %%
df["Age"].
# Out:
# 0       49
# 1       43
# 2       45
# 3       43
# 4       38
#         ..
# 7642    66
# 7643    36
# 7644    47
# 7645    53
# 7646    52
# Name: Age, Length: 7643, dtype: int32

# %%
df.drop(columns="BIRTH",inplace=True)

# %%
df
# Out:
#       KIDSDRIV  HOMEKIDS  YOJ  INCOME PARENT1  HOME_VAL MSTATUS GENDER  \
# 0            0         2   13   26763     Yes    141019      No      F
# 1            0         0    9  156060      No    381438     Yes      M
# 2            0         1   11    1965     Yes         0      No      F
# 3            0         1   10   62361      No    185738     Yes      F
# 4            0         1   10   34192     Yes         0      No      F
# ...        ...       ...  ...     ...     ...       ...     ...    ...
# 7642         0         0   11   67813      No    249997     Yes      F
# 7643         0         2   11   13490      No     95447     Yes      M
# 7644         0         1   11   44955      No    161808     Yes      M
# 7645         0         0   13   36835      No    167142     Yes      M
# 7646         0         0   13   58273      No    238850     Yes      F
#
#         EDUCATION    OCCUPATION  TRAVTIME     CAR_USE  BLUEBOOK     CAR_TYPE  \
# ...

# %%
df.select_dtypes(include="object")
# Out:
#      PARENT1 MSTATUS GENDER    EDUCATION    OCCUPATION     CAR_USE  \
# 0        Yes      No      F      Masters       Manager     Private
# 1         No     Yes      M    Bachelors   Blue Collar  Commercial
# 2        Yes      No      F          PhD    Home Maker     Private
# 3         No     Yes      F    Bachelors    Home Maker     Private
# 4        Yes      No      F  High School   Blue Collar  Commercial
# ...      ...     ...    ...          ...           ...         ...
# 7642      No     Yes      F    Bachelors  Professional     Private
# 7643      No     Yes      M  High School       Student  Commercial
# 7644      No     Yes      M    Bachelors  Professional     Private
# 7645      No     Yes      M  High School   Blue Collar  Commercial
# 7646      No     Yes      F      Masters        Lawyer     Private
#
#          CAR_TYPE           URBANICITY
# 0             SUV  Highly Urban/ Urban
# 1     Panel Truck  Highly Urban/ Urban
# 2         Minivan  Highly Urban/ Urban
# ...

# %%
df["PARENT1"]=df["PARENT1"].apply(lambda x:1 if x=="Yes" else 0)

# %%
df["MSTATUS"]=df["MSTATUS"].apply(lambda x:1 if x=="Yes" else 0)

# %%
df["GENDER"]=df["GENDER"].apply(lambda x:1 if x=="F" else 0)

# %%
df["CAR_USE"]=df["CAR_USE"].apply(lambda x:1 if x=="Private" else 0)

# %%
df["URBANICITY"]=df["URBANICITY"].apply(lambda x:1 if x=="Highly Urban/ Urban" else 0)

# %%
df.select_dtypes(include="object").nunique()
# Out:
# EDUCATION     5
# OCCUPATION    8
# CAR_TYPE      6
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df["EDUCATION"]=le.fit_transform(df["EDUCATION"])

# %%
df["OCCUPATION"]=le.fit_transform(df["OCCUPATION"])
df["CAR_TYPE"]=le.fit_transform(df["CAR_TYPE"])

# %%
df.head()
# Out:
#    KIDSDRIV  HOMEKIDS  YOJ  INCOME  PARENT1  HOME_VAL  MSTATUS  GENDER  \
# 0         0         2   13   26763        1    141019        0       1
# 1         0         0    9  156060        0    381438        1       0
# 2         0         1   11    1965        1         0        0       1
# 3         0         1   10   62361        0    185738        1       1
# 4         0         1   10   34192        1         0        0       1
#
#    EDUCATION  OCCUPATION  TRAVTIME  CAR_USE  BLUEBOOK  CAR_TYPE  OLDCLAIM  \
# 0          3           5        49        1     11500         3         0
# 1          1           0        29        0     25230         1      8207
# 2          4           3        21        1     20630         0         0
# 3          1           3        32        1     11540         3      3481
# 4          2           0        22        0     13670         3         0
#
#    CLM_FREQ  CLM_AMT  CAR_AGE  URBANICITY  Age
# ...

# %%
df["CLAIMED"]=df['CLM_AMT'].apply(lambda x:1 if x>0 else 0)

# %%
df
# Out:
#       KIDSDRIV  HOMEKIDS  YOJ  INCOME  PARENT1  HOME_VAL  MSTATUS  GENDER  \
# 0            0         2   13   26763        1    141019        0       1
# 1            0         0    9  156060        0    381438        1       0
# 2            0         1   11    1965        1         0        0       1
# 3            0         1   10   62361        0    185738        1       1
# 4            0         1   10   34192        1         0        0       1
# ...        ...       ...  ...     ...      ...       ...      ...     ...
# 7642         0         0   11   67813        0    249997        1       1
# 7643         0         2   11   13490        0     95447        1       0
# 7644         0         1   11   44955        0    161808        1       0
# 7645         0         0   13   36835        0    167142        1       0
# 7646         0         0   13   58273        0    238850        1       1
#
#       EDUCATION  OCCUPATION  ...  CAR_USE  BLUEBOOK  CAR_TYPE  OLDCLAIM  \
# ...

# %%
df.drop(columns="CLM_AMT",inplace=True)

# %%
X=df2.drop(columns="CLAIMED")
y=df2["CLAIMED"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=7)

# %%
mm=MinMaxScaler()
X_train=mm.fit_transform(X_train)
X_test=mm.transform(X_test)

# %%
lr2=LogisticRegression()
lr2.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr2.score(X_train,y_train)
# Out:
# 0.7320374869836862

# %%
y_predict=lr2.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_predict)

# %%
df["CLAIMED"].value_counts()
# Out:
# CLAIMED
# 0    5585
# 1    2058
# Name: count, dtype: int64

# %%
df2=pd.concat([df[df["CLAIMED"]==0].sample(2058),df[df["CLAIMED"]==1]])

# %%
df2["CLAIMED"].value_counts()
# Out:
# CLAIMED
# 0    2058
# 1    2058
# Name: count, dtype: int64
