# %% [markdown]
# # 1)Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
#Importing the required Libaries
import numpy as np
import pandas as pd
from datetime import datetime

# %%
#To Read the Data file
data_file=pd.read_csv('youtube_dislike_dataset.csv')

# %%
#The data_set
data_file
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title      published_at  \
# ...

# %%
#To view the top first 5 rows
data_file.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4       #NAME?                Why Retaining Walls Collapse
#
#                  channel_id          channel_title      published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  01-07-2021 10.00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  10-06-2021 16.00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy   20-09-2021 1.03
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  03-03-2021 10.00
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  07-12-2021 13.00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#To view the last 5 rows
data_file.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title      published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay   12-02-2021 5.03
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA   16-01-2021 5.39
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO   02-06-2021 9.00
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  20-10-2020 20.59
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  23-05-2021 21.00
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2) Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
#To find the info of the Dataframe
data_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#To find the shape of the Dataframe
data_file.shape
# Out:
# (37422, 12)

# %%
#To find the datatype of each catagory
data_file.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %% [markdown]
# # 3)Check for the Percentage of the missing values and drop or impute them.

# %%
#To view the percentage of null values of each catagory
data_file.isnull().sum()*100/len(data_file)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
file_copy=data_file.copy() #Taking a copy of the data

#Replacing the missing values with the mode
data_file['comments'].fillna(data_file['comments'].mode(),inplace=True)

# %%
#To view the null values after the replacement
data_file.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# # 4) Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
#To find the statistical summary for Numerical columns
data_file.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
#To find the statistical summary for categorical columns
data_file.describe(include='object')
# Out:
#        video_id  title                channel_id        channel_title  \
# count     37422  37422                     37422                37422
# unique    36964  37111                     10961                10880
# top      #NAME?    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq        459     21                       533                  533
#
#            published_at   tags description  \
# count             37422  37422       37422
# unique            30031  28788       35630
# top     18-09-2020 4.00
# freq                 18   3817         589
#
#                                                  comments
# count                                               37422
# unique                                              37264
# top     It's not bad! Congrats making it into Fortnite...
# freq                                                    2

# %% [markdown]
# # 5)Convert datatype of column published_at from object to pandas datetime.

# %%
#converting 'published_at' values to panadas datetime 
data_file['published_at']=pd.to_datetime(data_file['published_at'], format='%d-%m-%Y %H.%M')
data_file
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
#data type after converting to pandas datetime
data_file.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# # 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
#data_file['comments'].fillna(data_file['comments'].mode(),inplace=True)

# %%
#Inserting new column 'published_month'
data_file['published_month']=data_file['published_at'].dt.month

# %%
#Data_file after inserting new column
data_file
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 7) Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
#Replacing the published_month column
Replacing_month = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
data_file['published_month']=data_file['published_month'].replace(Replacing_month)

# %%
#data_file after Replacing the published_month column
data_file
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # 8) Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
data_file.duplicated('title').sum()
# Out:
# 311
