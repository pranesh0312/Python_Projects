# %% [markdown]
# ![New_GL_logo.png](data:image/png;base64,...)
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.
#
#
# #  Course 2 - Week04 - Day02 - Practice Exercise

# %% [markdown]
# -----

# %% [markdown]
# ##  <font color='blue'> Table Of Contents </font>
# - ### <font color='blue'> About dataset </font>
# - ### <font color='blue'> Importing necessary libraries and reading the dataset </font>
# - ### <font color='blue'> Data Visualization with matplotlib and seaborn libraries. </font>

# %% [markdown]
# ### <font color = 'green'> **About dataset**

# %% [markdown]
# This dataset consist of data From 1985 Ward's Automotive Yearbook.
#
# This data set consists of three types of entities:
# - (a) The specification of an auto in terms of various characteristics.
# - (b) Its assigned insurance risk rating.
# - (c) Its normalized losses in use as compared to other cars.
#
# The second rating corresponds to the degree to which the auto is more risky than its price indicates. Cars are initially assigned a risk factor symbol associated with its price. Then, if it is more risky (or less), this symbol is adjusted by moving it up (or down) the scale. Actuarians call this process "symboling". A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.
#
# The third factor is the relative average loss payment per insured vehicle year. This value is normalized for all autos within a particular size classification (two-door small, station wagons, sports/speciality, etc…), and represents the average loss per car per year.
#
# **Dataset Source:** https://www.kaggle.com/datasets/toramky/automobile-dataset

# %% [markdown]
# ### <font color = 'green'> **Import necessary libraries and read the dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_row',200)
pd.set_option('display.max_columns',200)
pd.set_option('display.width',100)

# %%
df = pd.read_csv('Automobile.csv')

# %% [markdown]
# <font size=3> Q. Display the first 5 records of the dataset

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration number_of_doors   body_style  \
# 0          3                168  alfa-romero       gas        std             two  convertible
# 1          3                168  alfa-romero       gas        std             two  convertible
# 2          1                168  alfa-romero       gas        std             two    hatchback
# 3          2                164         audi       gas        std            four        sedan
# 4          2                164         audi       gas        std            four        sedan
#
#   drive_wheels engine_location  wheel_base  length  width  height  curb_weight engine_type  \
# 0          rwd           front        88.6   168.8   64.1    48.8         2548        dohc
# 1          rwd           front        88.6   168.8   64.1    48.8         2548        dohc
# 2          rwd           front        94.5   171.2   65.5    52.4         2823        ohcv
# ...

# %% [markdown]
# <font size=3> Q. Display the shape of the dataset

# %%
df.shape
# Out:
# (201, 26)

# %% [markdown]
# <font size=3> Q. Display the basic info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %% [markdown]
# <font size=3> Q. Display the summary of the entire data and share your observations

# %%
df.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width      height  curb_weight  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000  201.000000   201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055   53.766667  2555.666667
# std      1.254802          33.572966    6.066366   12.322175    2.101471    2.447822   517.296727
# min     -2.000000          65.000000   86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000   52.000000  2169.000000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000   55.500000  2926.000000
# max      3.000000         256.000000  120.900000  208.100000   72.000000   59.800000  4066.000000
#
#        engine_size        bore      stroke  compression_ratio  horsepower     peak_rpm  \
# ...

# %%
df.describe(include=object)
# Out:
#           make fuel_type aspiration number_of_doors body_style drive_wheels engine_location  \
# count      201       201        201             201        201          201             201
# unique      22         2          2               2          5            3               2
# top     toyota       gas        std            four      sedan          fwd           front
# freq        32       181        165             114         94          118             198
#
#        engine_type number_of_cylinders fuel_system
# count          201                 201         201
# unique           6                   7           8
# top            ohc                four        mpfi
# freq           145                 157          92

# %% [markdown]
# ### <font color = 'green'> **Histogram**
#
# - A **histogram** is a univariate plot which helps us understand the distribution of a continuous numerical variable.
# - It breaks the range of the continuous variables into a intervals of equal length and then counts the number of observations in each interval.
# - We will use the *histplot()* function of seaborn to create histograms.

# %% [markdown]
# <font size=3> Q. Plot a histogram for the feature 'price'

# %%
sns.histplot(data=df, x="price")

plt.show()

# %% [markdown]
# **Let's see how we can customize a histogram.**

# %% [markdown]
# <font size=3> Q. Plot a histogram for the feature 'price' with below constraints
#
# - Title as 'Histogram: Price"
# - Range of values on x-axis ranging from 3000 to 50000
# - Range of values on y-axis ranging from 0 to 70
# - Give the respective labels to both x and y axis, and the bars in the plot should be of orange colour.

# %%
sns.histplot(data=df, x="price")
plt.xlim(3000,5000)
plt.ylim(0,70)
plt.title('Price')
plt.xlabel("price of cars")
plt.ylabel("Frequemcy")
plt.show()

# %% [markdown]
# **We can specify the number of intervals (or groups or bins) to create by setting the *bins* parameter.**
#
# - If not specified it is passed to [numpy.histogram_bin_edges()](https://numpy.org/doc/stable/reference/generated/numpy.histogram_bin_edges.html#numpy.histogram_bin_edges)

# %% [markdown]
# <font size=3>  Q. Plot a histogram for feature 'price' such that the entire range of values in the feature 'price' is clubbed into 5 bins in total.

# %%
sns.histplot(data=df, x="price",bins=5)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# <font size=3> Q. Similarly with 20 bins

# %%
sns.histplot(data=df, x="price",bins=20)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ### <font color = 'green'> **Boxplot**
#
# - A **boxplot**, or a **box-and-whisker plot**, shows the distribution of numerical data and skewness through displaying the data quartiles
# - It is also called a **five-number summary plot**, where the five-number summary includes the minimum value, first quartile, median, third quartile, and the maximum value.
# - The *boxplot()* function of seaborn can be used to create a boxplot.

# %% [markdown]
# <font size=3> Q. Create a boxplot for the feature 'curb_weight'

# %%
sns.boxplot(x=df["curb_weight"])
# Out:
# <Axes: xlabel='curb_weight'>

# %% [markdown]
# **Let's see how we can customize a boxplot.**

# %% [markdown]
# <font size=3> Q. Create a boxplot for the feature 'horsepower' with below constraints
#
# - Title as 'Boxplot:Horsepower'
# - Range of values on x-axis ranging from 30 to 300
# - Give the respective labels to the axis, and specify any colour to the bozxes in the boxplot.

# %%
sns.boxplot(x=df["horsepower"])
plt.title("Horsepower")
# Out:
# Text(0.5, 1.0, 'Horsepower')

# %% [markdown]
# - In a boxplot, when the median is closer to the left of the box and the whisker is shorter on the left end of the box, we say that the distribution is **positively skewed (skewed right)**.
# - Similarly, when the median is closer to the right of the box and the whisker is shorter on the right end of the box, we say that the distribution is **negatively skewed (skewed left)**.

# %% [markdown]
# <font size=3> Q. Create a box plot for the feature 'price'

# %%
sns.boxplot(x=df["price"])
plt.show()

# %% [markdown]
# <font size=3> Q. Create a boxplot of body_style v/s price

# %%
sns.boxplot(x=df['body_style'],y=df['price'],data=df)
plt.show()

# %% [markdown]
# ### <font color = 'green'> **Pair Plot**
#
# * A **pairplot** shows the relationship between two numeric variables for each pair of columns in the dataset.
# * It creates a grid of axes such that each variable in data will be shared in the y-axis across a single row and in the x-axis across a single column.
# * The *pairplot()* function of seaborn can be used to create such a plot.

# %% [markdown]
# <font size=3> Q. Create a pairplot using the features 'normalized_losses', 'wheel_base', 'curb_weight', 'engine_size', 'price', 'peak_rpm'.

# %%
sns.pairplot(df, vars=['normalized_losses', 'wheel_base', 'curb_weight', 'engine_size', 'price', 'peak_rpm'])
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **We can add the *hue* parameter in pairplot to create a semantic mapping.**
#
# - It changes the default marginal plot to a layered kde plot.
#
# **Also, we can add *vars* parameter to assign a list of variables from the dataset for which we want to create the pairplot.**

# %% [markdown]
# <font size=3> Q. Create a pairplot with vars = ['wheel_base', 'curb_weight', 'engine_size', 'price'] and hue as number of doors.

# %%
sns.pairplot(df,hue='number_of_doors', vars=['wheel_base', 'curb_weight', 'engine_size', 'price'])
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <font size=3> Q. Set corner=True to the above plot to display only the lower triangle of a pairplot.

# %%
sns.pairplot(df,hue='number_of_doors', vars=['wheel_base', 'curb_weight', 'engine_size', 'price'],corner=True)
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### <font color = 'green'> **Heatmap**
#
# * A **heatmap** is a graphical representation of data as a color-encoded matrix.
# * It is a great way of representing  the correlation for each pair of columns in the data.
# * The *heatmap()* function of seaborn helps us to create such a plot.

# %% [markdown]
# <font size=3> Q. Create a heatmap for all the numerical features in the dataset.

# %%
corr=df.corr(numeric_only=True)
corr
# Out:
#                    symboling  normalized_losses  wheel_base    length     width    height  \
# symboling           1.000000           0.474993   -0.535987 -0.365404 -0.242423 -0.550160
# normalized_losses   0.474993           1.000000    0.007815  0.103659  0.153752 -0.335476
# wheel_base         -0.535987           0.007815    1.000000  0.876024  0.814507  0.590742
# length             -0.365404           0.103659    0.876024  1.000000  0.857170  0.492063
# width              -0.242423           0.153752    0.814507  0.857170  1.000000  0.306002
# height             -0.550160          -0.335476    0.590742  0.492063  0.306002  1.000000
# curb_weight        -0.233118           0.178547    0.782097  0.880665  0.866201  0.307581
# engine_size        -0.110581           0.174788    0.572027  0.685025  0.729436  0.074694
# bore               -0.146355           0.007498    0.495210  0.610324  0.545028  0.186701
# ...

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# **We can set the *annot* parameter to *True* for displaying the numeric value in each cell.**
#
# - To remove the color bar, the *cbar* parameter can be set to *False*.

# %% [markdown]
# <font size=3> Q. Display the correlation values on the heatmap.

# %%
sns.heatmap(corr,annot=True,cbar=False)
plt.show()

# %% [markdown]
# **We can apply a different colormap with the *cmap* parameter for better visual appeal.**

# %% [markdown]
# <font size=3> Q. Apply a different colormap with the *cmap* parameter for better visual appeal.

# %% [markdown]
# ### <font color = 'green'> **Countplot**
# - Countplot displays the number of observations in each categorical level using the bars
# - It is Similar to bar plot
# - The count plots can be plotted horizontally or vertically

# %% [markdown]
# <font size=3> Q. Analyse the number of observations of each class in the feature 'number_of_cylinders' using the bars with count plot.

# %%
ax = sns.countplot(x="number_of_cylinders", data=df)

# %% [markdown]
# ### <font color = 'green'> **Displot**
# - Displot helps in understanding the variation in the data distribution
# - Provides access to several approaches for visualizing the distribution of data
# - Kind parameter helps in selecting the approach
# - histplot() is the default kind of plot when displot() function is called.
# - kdeplot() can be plotted by specifying the parameter kind=’kde’

# %% [markdown]
# <font size=3> Q. Analyse the variation in the data distribution of the feature engine_type using multiple distribution plots.

# %%
sns.displot(df["engine_type"], kde=False)

plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <font size=3> Q. Make use of kde parameter to see how the distribution appears.

# %%
sns.displot(df["engine_type"], kde=True)

plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ----
# ### Happy Learning:)
# ----
