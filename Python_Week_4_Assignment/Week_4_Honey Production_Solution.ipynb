# %% [markdown]
# # 1) Import required libraries and read the dataset.

# %%
#Importing the required Libaries

import numpy as np
import pandas as pd
from datetime import datetime 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#To Read the Data file

data=pd.read_csv('honeyproduction.csv')

# %%
#The data_set

data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# The Dataset discribes the honey production supply and demand in America by state from 1998 to 2012.

# %% [markdown]
# # 2) Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
#To view some sample of data

data.sample(3)
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 501    VA   6000.0           39   234000.0   56000.0        3.45   807000.0
# 101    ME  11000.0           21   231000.0  143000.0        0.75   173000.0
# 338    VA   8000.0           37   296000.0   59000.0        2.20   651000.0
#
#      year
# 501  2009
# 101  2000
# 338  2005

# %%
#To know the shape of the data 

data.shape
# Out:
# (626, 8)

# %% [markdown]
# The dataset consists of 626 rows and 8 columns

# %%
#To know the datatypes of the dataset

data.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
#To know the info() of the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %% [markdown]
# From the info() and dtypes function,it shows that there are 5 float (numcol,totalprod,stocks,priceperlb,prodvalue)and 2 int (yieldpercol and year) and one object datatype(state) in the Dataset

# %%
#To find the duplicate values

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no Duplicate values in the given Dataset

# %%
#To get the null values in the Dataset

data.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %% [markdown]
# There is no null values in the given Dataset

# %% [markdown]
# # 3) Display the percentage distribution of the data in each year using the pie chart.

# %%
a=data['year'].value_counts()
plt.pie(x=a.index,labels=a.values,autopct='%.1f%%')
plt.title('Distribution of the data in each year')
plt.show()

# %% [markdown]
# # 4) Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data["priceperlb"],kde=True)
plt.title('distribution of the price per lb ')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Inference:
#
# 1)From the above plot we can see that Highest average amount in the 1.5 priceperlb(Unit is dollars).
#
# 2)From the above plot we can see that Minimum average amount in the 4.0 priceperlb(Unit is dollars).
#
# 3)The KDE graph Describes the Probability Distribution of priceperlb values.

# %% [markdown]
# # 5) Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(x=data["prodvalue"], y=data["numcol"], data=data)
plt.title("relationship between the numcol and prodval")
plt.show()

# %% [markdown]
# Inference:
#
# 1)From the plot,it shows an increase pattern between the prodvalue and numcol
#
# 2)This increase pattern describes that the value of production depends on the Number of honey producing colonies
#
# 3)In the plot,we can see that the range(0 to 100000) has the more values of production

# %% [markdown]
# # 6) Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
ax = sns.boxplot(data["year"]) 
plt.title('Year_Catagorical_value')
plt.show()

# %% [markdown]
# Inference:
#
# 1)The year catagory ranges from 1998 to 2012
#
# 2)The Maximum year for honey production is 2012
#
# 3)The Minimun year for honey production is 1998
#
# 4)The Median year for honey production is 2005

# %%
bx=sns.boxplot(data["prodvalue"])
plt.title('Year_Numerical_value')
plt.show()

# %% [markdown]
# Inference:
#
# 1)The prodvalue ranges from 0 to 1
#
# 2)The Maximum year for honey production is 1
#
# 3)The Minimun year for honey production is 0
#
# 4)The Median year for honey production is 0.5

# %% [markdown]
# # 7) Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(data, hue='year',vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue'],palette='bright')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Inference:
#
# 1)From the plot,it describes that the totalprod and prodvalue increases when the number of honey producing colonies increases
#
# 2)The Total production increases with the increase in Value of production
#
# 3)The totalprod and prodvalue increases in the year 2011

# %% [markdown]
# # 8) Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
corr=data.corr(numeric_only=True)#To find the correlation matrix

# %%
sns.heatmap(corr, cbar=0, linewidths=2,vmax=1, vmin=0, square=True, cmap='BuPu', annot = True)
plt.title('Heat_Map')
plt.show()

# %% [markdown]
# Inference:
#
# 1)There is an high positive correlation between the catagory numcol and totalprod
#
# 2)There is an Negative correlation between the catagory priceperlb and yieldpercol
